# %%
import langchain

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
#simple LLM call with streaming
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage,SystemMessage

#A HumanMessage is a message that is passed in from a user to the model.
#The system message is usually passed in as the first of a sequence of input messages.

# %%
model=init_chat_model("groq:llama-3.1-8b-instant")
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000024655AFBFB0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000246568EF1A0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
#create messages
messages=[
    SystemMessage("you are a helpful AI assistant"),
    HumanMessage("what are the top 3 benefits of using Langchain?")
]

# %%
#invoke the model
response=model.invoke(messages)
print(response)
# Out:
# content='Langchain is an open-source framework for building conversational AI models. Based on my knowledge, here are the top 3 benefits of using Langchain:\n\n1. **Conversational AI Development**: Langchain provides a modular and flexible framework for building conversational AI models, allowing developers to create complex conversation flows and integrate multiple AI models. This makes it ideal for building conversational interfaces, chatbots, and voice assistants.\n\n2. **Knowledge Graph Integration**: Langchain allows developers to integrate knowledge graphs, which are a type of data structure that represents knowledge as a network of entities and their relationships. This enables Langchain models to access and reason about vast amounts of information, making them more informed and context-aware.\n\n3. **Efficient Model Development and Deployment**: Langchain provides a range of tools and libraries that streamline the development and deployment of conversational AI models. This includes pre-built components for natural language processing (NLP), model serving, and integration with popular frameworks like Python and TensorFlow. As a result, developers can build and deploy conversational AI models more quickly and efficiently.\n\nThese benefits make Langchain a popular choice among developers and researchers working on conversational AI projects.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 238, 'prompt_tokens': 53, 'total_tokens': 291, 'completion_time': 0.333167394, 'completion_tokens_details': None, 'prompt_time': 0.002594368, 'prompt_tokens_details': None, 'queue_time': 0.055525812, 'total_time': 0.335761762}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019b412e-d9f3-73a1-b9e8-28b5aee21450-0' usage_metadata={'input_tokens': 53, 'output_tokens': 238, 'total_tokens': 291}

# %%
print(response.content)
# Out:
# Langchain is an open-source framework for building conversational AI models. Based on my knowledge, here are the top 3 benefits of using Langchain:
#
# 1. **Conversational AI Development**: Langchain provides a modular and flexible framework for building conversational AI models, allowing developers to create complex conversation flows and integrate multiple AI models. This makes it ideal for building conversational interfaces, chatbots, and voice assistants.
#
# 2. **Knowledge Graph Integration**: Langchain allows developers to integrate knowledge graphs, which are a type of data structure that represents knowledge as a network of entities and their relationships. This enables Langchain models to access and reason about vast amounts of information, making them more informed and context-aware.
#
# 3. **Efficient Model Development and Deployment**: Langchain provides a range of tools and libraries that streamline the development and deployment of conversational AI models. This includes pre-built components for natural language processing (NLP), model serving, and integration with popular frameworks like Python and TensorFlow. As a result, developers can build and deploy conversational AI models more quickly and efficiently.
#
# These benefits make Langchain a popular choice among developers and researchers working on conversational AI projects.

# %%
res=model.invoke([HumanMessage("Give machine learning definition in simple words")])

# %%
print(res.content)
# Out:
# **Machine Learning (ML) Definition:**
#
# Machine learning is a way that computers learn and improve their performance by themselves, without being explicitly programmed.
#
# Think of it like this: Imagine you have a child who is learning to recognize different animals. At first, the child might not know what a cat or a dog looks like. But as the child sees more pictures and examples, they start to recognize patterns and learn what makes a cat a cat and a dog a dog.
#
# Machine learning is similar. Computers are shown examples of data (like pictures or information), and they use that data to learn and improve their performance on a particular task, such as:
#
# - Recognizing images
# - Predicting outcomes
# - Identifying patterns
#
# The more data the computer is shown, the better it becomes at performing the task. And, just like the child, the computer can make mistakes, but it can also learn from those mistakes and get even better over time.

# %%
#streaming example
for chunk in model.stream(messages):
    print(chunk.content,end="",flush=True)
# Out:
# Langchain is a technology company that provides a suite of tools and services for building multi-modal AI systems. The top 3 benefits of using Langchain are:
#
# 1. **Improved Data Integration**: Langchain's platform allows for seamless integration of various data sources, including text, images, audio, and videos. This enables users to build more comprehensive AI models that can draw insights from diverse data types, leading to more accurate and robust decision-making.
#
# 2. **Enhanced Conversational AI**: Langchain's tools enable developers to create more natural and human-like conversational interfaces. By leveraging the company's multi-modal AI capabilities, users can build chatbots, virtual assistants, and other conversational AI systems that can understand and respond to complex queries in a more intuitive and engaging way.
#
# 3. **Streamlined Model Development**: Langchain's platform provides a range of pre-built models and tools that can help developers streamline their AI model development process. By leveraging these resources, users can build and deploy AI models more quickly and efficiently, reducing the time and effort required to bring their projects to market.
#
# These benefits can help users unlock the full potential of their AI projects and achieve greater success in their respective fields.
